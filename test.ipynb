# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/home/catkin_ws/src/data_log.csv")

data
# Out:
#              Time    Pose.x    Pose.y    Pose.z   Pose.qx   Pose.qy   Pose.qz  \
# 0    1.730264e+09 -0.261634  0.065632  0.403751 -0.226112  0.735057 -0.598421
# 1    1.730264e+09 -0.262370  0.059545  0.404343 -0.234797  0.752601 -0.572757
# 2    1.730264e+09 -0.262981  0.053486  0.404879 -0.243669  0.769275 -0.546554
# 3    1.730264e+09 -0.263470  0.047452  0.405362 -0.252708  0.785076 -0.519819
# 4    1.730264e+09 -0.263840  0.041452  0.405792 -0.261885  0.799975 -0.492606
# ..            ...       ...       ...       ...       ...       ...       ...
# 371  1.730264e+09 -0.118596 -0.507560  0.610215 -0.304984  0.605106  0.671633
# 372  1.730264e+09 -0.118596 -0.507560  0.610215 -0.304984  0.605106  0.671633
# 373  1.730264e+09 -0.118596 -0.507560  0.610215 -0.304984  0.605106  0.671633
# 374  1.730264e+09 -0.118596 -0.507560  0.610215 -0.304984  0.605106  0.671633
# 375  1.730264e+09 -0.118596 -0.507560  0.610215 -0.304984  0.605106  0.671633
#
# ...

# %%
pose_data = data[["Pose.x", "Pose.y", "Pose.z"]]

data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pose_data = data[[" Pose.x", " Pose.y", " Pose.z"]]
#       3 data.head()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
# ...

# %%
from matplotlib import pyplot as plt

plt.scatter(pose_data["Pose.x"], pose_data["Pose.y"])
plt.xlabel("Pose.x")
plt.ylabel("Pose.y")
plt.title("Scatter plot of Pose.x vs Pose.y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/projections/__init__.py:58, in get_projection_class(projection)
#      57 try:
# ---> 58     return projection_registry.get_projection_class(projection)
#      59 except KeyError:
#
# File /usr/lib/python3/dist-packages/matplotlib/projections/__init__.py:25, in ProjectionRegistry.get_projection_class(self, name)
#      22 """
#      23 Get a projection class from its *name*.
#      24 """
# ---> 25 return self._all_projection_types[name]
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 from matplotlib import pyplot as plt
#       3 fig = plt.figure()
# ----> 4 ax = fig.gca(projection="3d")
# ...
